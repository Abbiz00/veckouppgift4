# %%
1 Läsa och förstå kod - diskutera i grupp
Skriv ner vad du tror kommer skrivas ut. Skriv sedan in koden i din IDE, exakt som den står, och kör den. Fick du samma resultat som du trodde? Om inte, varför?

# %% [markdown]
#  1a) Funktionen skriver ut test

# %%
def foo(t):
    print("test")

foo("hej")
# Out:
# test

# %% [markdown]
# 1b) Funktionen skriver ut 3 5

# %%
def fun1(x, y):
    return x * y

print(3, 5)
# Out:
# 3 5

# %% [markdown]
# 1c) Funktionern skriver ut 15  (3*5)

# %%
def fun1(x, y):
    return x * y

print(fun1(3, 5))
# Out:
# 15

# %% [markdown]
# 1d)
# fun2(x) = fun2(2) = 5 * 2 = 10
# fun2(y) = fun2(3) = 5 * 3 = 15
# summan blir 10 + 15 = 25
# fun2(25) = 5 * 25 = 125

# %%
def fun2(i):
    return 5 * i

x = 2
y = 3
a = fun2(fun2(x) + fun2(y))
print(a)
# Out:
# 125

# %% [markdown]
# 1e) skriver u 7  5+2

# %%
a = 5
def fun3(a):
    a += 1

a += 2
print(a)
# Out:
# 7

# %% [markdown]
#  skriver ut 18 2*3*3

# %%
def foo(i):
    return 2*i*i

def goo(x, y):
    return x(y)

a = goo(foo, 3);
print(a)
# Out:
# 18

# %% [markdown]
# 1g Funktionen "isinstance" kan kontrollera en variabels datatyp. Vad gör funktionen is_number? Går det att förbättra koden? Funktionen svara True på både int och float

# %%
def is_number(x):
    if isinstance(x, int):
        return True
    elif isinstance(x, float):
        return True
    return False

print(is_number(5.5))
print(is_number(42))
# Out:
# True
# True

# %% [markdown]
# Delat upp i två funktioner en för kontroll av int eller float.

# %%
def is_number_int(x):
    return isinstance(x, int)   #isinstance ger en True eller false så man behöver inte if satsen

def is_number_float(x):
    return isinstance(x, float)

print(f"Är 5.5 en int? {is_number_int(5.5)}")
print(f"Är 42 en int? {is_number_int(42)}")
print("")
print(f"Är 5.5 en float? {is_number_float(5.5)}")
print(f"Är 42 en float? {is_number_float(42)}")
# Out:
# Är 5.5 en int? False
# Är 42 en int? True
#
# Är 5.5 en float? True
# Är 42 en float? False
